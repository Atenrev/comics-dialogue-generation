# %%
import pandas as pd

# %%
df_ours = pd.read_csv("COMICS/text_cloze_test_easy_full.csv", ',')
df_org = pd.read_csv("folds/text_cloze_test_easy.csv", ',')
# Out:
# /home/smasip/anaconda3/envs/comics/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3251: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# /home/smasip/anaconda3/envs/comics/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3251: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_org.head()
# Out:
#    book_id  page_id  answer_panel_id  context_panel_0_id  context_panel_1_id  \
# 0     3451        5                4                   1                   2
# 1     3451        6                4                   1                   2
# 2     3451        7                4                   1                   2
# 3     3451        9                3                   0                   1
# 4     3451       10                3                   0                   1
#
#    context_panel_2_id                                   context_text_0_0  \
# 0                   3                          let ' s get him , pooch !
# 1                   3  pepper UNK on the trail ! the hound ' s no goo...
# 2                   3                is suddenly snatched into the air !
# 3                   2          UNK for breath , they reach the stream ..
# 4                   2  donit pull any UNK on me ! hold this in place ...
#
# ...

# %%
int_df = pd.merge(df_ours, df_org, how='inner', suffixes=(None, "_unk"),
on=['book_id', 'page_id', 'answer_panel_id', 'context_panel_0_id', 'context_panel_1_id', 'context_panel_2_id'], 
)

# %%
int_df.head()
# Out:
#    book_id  page_id  answer_panel_id  context_panel_0_id  context_panel_1_id  \
# 0     3451        5                4                   1                   2
# 1     3451        6                4                   1                   2
# 2     3451        7                4                   1                   2
# 3     3451        9                3                   0                   1
# 4     3451       10                3                   0                   1
#
#    context_panel_2_id                                   context_text_0_0  \
# 0                   3                         let ' s get him , squire !
# 1                   3  championship bulld on the trail ! the actions ...
# 2                   3                   is suddenly souls into the air !
# 3                   2         hendling for breath , they reach the 77 ..
# 4                   2  donit pull any leadep on me ! hold this in pla...
#
# ...

# %%
int_df.to_csv("COMICS/text_cloze_test_easy.csv", index=False)
